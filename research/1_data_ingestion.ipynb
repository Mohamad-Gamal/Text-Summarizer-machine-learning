# %%
import os
# %pwd
# Out:
# 'c:\\Users\\gimep\\Downloads\\workspace\\text_summarizer\\research'

# %%
os.chdir(r"C:/Users/gimep/Downloads/workspace/text_summarizer/")
# %pwd
# Out:
# 'C:\\Users\\gimep\\Downloads\\workspace\\text_summarizer'

# %%
from dataclasses import dataclass
from pathlib import Path

# %%
@dataclass
class DataIngestionConfig:
    root_dir: Path
    source_URL: Path
    local_data_file: Path
    unzip_dir: Path

# %%
from src.textsummarizer.constants import *
from src.textsummarizer.utils.common import read_yaml, create_directories

# %%
# Configuration Updates

# %%
class ConfigurationManager():
    def __init__(self, config_path=CONFIG_FILE_PATH,
                    params_path=PARAMS_FILE_PATH):
        self.config=read_yaml(config_path)
        self.params=read_yaml(params_path)
        create_directories([self.config.artifacts_root])

    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config=self.config.data_ingestion
        create_directories([config.root_dir])
        data_ingestion_config=DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir
        )
        return data_ingestion_config

# %%
import os
import urllib.request as request
import zipfile
from src.textsummarizer.logging import logger

# %%
class DataIngestion:
    def __init__(self,config:DataIngestionConfig):
        self.config=config

    def download_file(self):
        if not os.path.exists(self.config.local_data_file):
            filename, headers = request.urlretrieve(
                url = self.config.source_URL,
                filename = self.config.local_data_file
            )
            logger.info(f"File is downloaded")
        else:
            logger.info(f"File already exits")

    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %% [markdown]
# Components

# %%
#Components

# %%
class DataIngestion:
    def __init__(self,config:DataIngestionConfig):
        self.config=config

    def download_file(self):
        if not os.path.exists(self.config.local_data_file):
            filename, headers = request.urlretrieve(
                url = self.config.source_URL,
                filename = self.config.local_data_file
            )
            logger.info(f"File is downloaded")
        else:
            logger.info(f"File already exits")

    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
config=ConfigurationManager()
data_ingestion_config=config.get_data_ingestion_config()
data_ingestion=DataIngestion(config=data_ingestion_config)

data_ingestion.download_file()
data_ingestion.extract_zip_file()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python311\Lib\logging\__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 690, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 659, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 449, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 445, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# ValueError: unsupported format character ':' (0x3a) at index 26
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Python311\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 701, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 469, in dispatch_shell
#     await result
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 379, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 899, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 471, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\zmqshell.py", line 632, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\32785271.py", line 1, in <module>
#     config=ConfigurationManager()
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\1310873614.py", line 4, in __init__
#     self.config=read_yaml(config_path)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ensure\main.py", line 849, in __call__
#     return_val = self.f(*args, **kwargs)
#   File "C:\Users\gimep\Downloads\workspace\text_summarizer\src\textsummarizer\utils\common.py", line 27, in read_yaml
#     logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# Message: 'yaml file: config\\config.yaml loaded successfully'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python311\Lib\logging\__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 690, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 659, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 449, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 445, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# ValueError: unsupported format character ':' (0x3a) at index 26
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Python311\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 701, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 469, in dispatch_shell
#     await result
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 379, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 899, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 471, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\zmqshell.py", line 632, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\32785271.py", line 1, in <module>
#     config=ConfigurationManager()
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\1310873614.py", line 4, in __init__
#     self.config=read_yaml(config_path)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ensure\main.py", line 849, in __call__
#     return_val = self.f(*args, **kwargs)
#   File "C:\Users\gimep\Downloads\workspace\text_summarizer\src\textsummarizer\utils\common.py", line 27, in read_yaml
#     logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# Message: 'yaml file: config\\config.yaml loaded successfully'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python311\Lib\logging\__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 690, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 659, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 449, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 445, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# ValueError: unsupported format character ':' (0x3a) at index 26
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Python311\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 701, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 469, in dispatch_shell
#     await result
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 379, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 899, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 471, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\zmqshell.py", line 632, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\32785271.py", line 1, in <module>
#     config=ConfigurationManager()
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\1310873614.py", line 5, in __init__
#     self.params=read_yaml(params_path)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ensure\main.py", line 849, in __call__
#     return_val = self.f(*args, **kwargs)
#   File "C:\Users\gimep\Downloads\workspace\text_summarizer\src\textsummarizer\utils\common.py", line 27, in read_yaml
#     logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# Message: 'yaml file: params.yaml loaded successfully'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python311\Lib\logging\__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 690, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 659, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 449, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 445, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# ValueError: unsupported format character ':' (0x3a) at index 26
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Python311\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 701, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 469, in dispatch_shell
#     await result
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 379, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 899, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 471, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\zmqshell.py", line 632, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\32785271.py", line 1, in <module>
#     config=ConfigurationManager()
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\1310873614.py", line 5, in __init__
#     self.params=read_yaml(params_path)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ensure\main.py", line 849, in __call__
#     return_val = self.f(*args, **kwargs)
#   File "C:\Users\gimep\Downloads\workspace\text_summarizer\src\textsummarizer\utils\common.py", line 27, in read_yaml
#     logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# Message: 'yaml file: params.yaml loaded successfully'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python311\Lib\logging\__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 690, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 659, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 449, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 445, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# ValueError: unsupported format character ':' (0x3a) at index 26
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Python311\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 701, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 469, in dispatch_shell
#     await result
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 379, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 899, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 471, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\zmqshell.py", line 632, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\32785271.py", line 1, in <module>
#     config=ConfigurationManager()
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\1310873614.py", line 6, in __init__
#     create_directories([self.config.artifacts_root])
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ensure\main.py", line 807, in __call__
#     return self.f(*args, **kwargs)
#   File "C:\Users\gimep\Downloads\workspace\text_summarizer\src\textsummarizer\utils\common.py", line 45, in create_directories
#     logger.info(f"created directory at: {path}")
# Message: 'created directory at: artifacts'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python311\Lib\logging\__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 690, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 659, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 449, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 445, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# ValueError: unsupported format character ':' (0x3a) at index 26
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Python311\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 701, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 469, in dispatch_shell
#     await result
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 379, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 899, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 471, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\zmqshell.py", line 632, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\32785271.py", line 1, in <module>
#     config=ConfigurationManager()
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\1310873614.py", line 6, in __init__
#     create_directories([self.config.artifacts_root])
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ensure\main.py", line 807, in __call__
#     return self.f(*args, **kwargs)
#   File "C:\Users\gimep\Downloads\workspace\text_summarizer\src\textsummarizer\utils\common.py", line 45, in create_directories
#     logger.info(f"created directory at: {path}")
# Message: 'created directory at: artifacts'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python311\Lib\logging\__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 690, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 659, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 449, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 445, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# ValueError: unsupported format character ':' (0x3a) at index 26
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Python311\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 701, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 469, in dispatch_shell
#     await result
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 379, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 899, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 471, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\zmqshell.py", line 632, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\32785271.py", line 2, in <module>
#     data_ingestion_config=config.get_data_ingestion_config()
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\1310873614.py", line 10, in get_data_ingestion_config
#     create_directories([config.root_dir])
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ensure\main.py", line 807, in __call__
#     return self.f(*args, **kwargs)
#   File "C:\Users\gimep\Downloads\workspace\text_summarizer\src\textsummarizer\utils\common.py", line 45, in create_directories
#     logger.info(f"created directory at: {path}")
# Message: 'created directory at: artifacts/data_ingestion'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python311\Lib\logging\__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 690, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 659, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 449, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 445, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# ValueError: unsupported format character ':' (0x3a) at index 26
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Python311\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 701, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 469, in dispatch_shell
#     await result
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 379, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 899, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 471, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\zmqshell.py", line 632, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\32785271.py", line 2, in <module>
#     data_ingestion_config=config.get_data_ingestion_config()
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\1310873614.py", line 10, in get_data_ingestion_config
#     create_directories([config.root_dir])
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ensure\main.py", line 807, in __call__
#     return self.f(*args, **kwargs)
#   File "C:\Users\gimep\Downloads\workspace\text_summarizer\src\textsummarizer\utils\common.py", line 45, in create_directories
#     logger.info(f"created directory at: {path}")
# Message: 'created directory at: artifacts/data_ingestion'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python311\Lib\logging\__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 690, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 659, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 449, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 445, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# ValueError: unsupported format character ':' (0x3a) at index 26
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Python311\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 701, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 469, in dispatch_shell
#     await result
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 379, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 899, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 471, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\zmqshell.py", line 632, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\32785271.py", line 5, in <module>
#     data_ingestion.download_file()
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\3467534831.py", line 13, in download_file
#     logger.info(f"File already exits")
# Message: 'File already exits'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python311\Lib\logging\__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 690, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 659, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 449, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\logging\__init__.py", line 445, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# ValueError: unsupported format character ':' (0x3a) at index 26
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Python311\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Python311\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 701, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 469, in dispatch_shell
#     await result
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 379, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\kernelbase.py", line 899, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\ipkernel.py", line 471, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\ipykernel\zmqshell.py", line 632, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\gimep\Downloads\workspace\text_summarizer\.textenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\32785271.py", line 5, in <module>
#     data_ingestion.download_file()
#   File "C:\Users\gimep\AppData\Local\Temp\ipykernel_14656\3467534831.py", line 13, in download_file
#     logger.info(f"File already exits")
# Message: 'File already exits'
# Arguments: ()
