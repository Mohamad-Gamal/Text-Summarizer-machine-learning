# %%
# !nvidia-smi
# Out:
# Mon Oct 20 21:38:31 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# ...

# %%
# !pip install transformers[sentencepiece] datasets sacrebleu rouge_score py7zr -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.0/97.0 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.7/51.7 kB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 429.9/429.9 kB 16.7 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade accelerate
# !pip uninstall -y transformers accelerate
# !pip install transformers accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.8/375.8 kB 11.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.10.1
#     Uninstalling accelerate-1.10.1:
#       Successfully uninstalled accelerate-1.10.1
# ...
# Found existing installation: transformers 4.57.1
# Uninstalling transformers-4.57.1:
#   Successfully uninstalled transformers-4.57.1
# Found existing installation: accelerate 1.11.0
# Uninstalling accelerate-1.11.0:
#   Successfully uninstalled accelerate-1.11.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.9 MB/s eta 0:00:00
# ...
#   Using cached accelerate-1.11.0-py3-none-any.whl.metadata (19 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 91.0 MB/s eta 0:00:00
# Using cached accelerate-1.11.0-py3-none-any.whl (375 kB)
# ...

# %%
from transformers import pipeline, set_seed
from datasets import load_dataset, load_from_disk
import matplotlib.pyplot as plt
from datasets import load_dataset
import pandas as pd

from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

from nltk.tokenize import sent_tokenize

from tqdm import tqdm
import torch

# %%
from transformers import AutoTokenizer, PegasusForConditionalGeneration

model = PegasusForConditionalGeneration.from_pretrained("google/pegasus-xsum")
tokenizer = AutoTokenizer.from_pretrained("google/pegasus-xsum")

ARTICLE_TO_SUMMARIZE = (
    "PG&E stated it scheduled the blackouts in response to forecasts for high winds "
    "amid dry conditions. The aim is to reduce the risk of wildfires. Nearly 800 thousand customers were "
    "scheduled to be affected by the shutoffs which were expected to last through at least midday tomorrow."
)
inputs = tokenizer(ARTICLE_TO_SUMMARIZE, max_length=1024, return_tensors="pt")

# Generate Summary
summary_ids = model.generate(inputs["input_ids"])
tokenizer.batch_decode(summary_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at google/pegasus-xsum and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# ...

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
import torch
import intel_extension_for_pytorch as ipex

# Move model and data to Intel GPU
device = torch.device("xpu")
print(torch.xpu.is_available())   # Should return True
print(torch.xpu.device_count())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
#       2 import torch
# ----> 3 import intel_extension_for_pytorch as ipex
#       5 # Move model and data to Intel GPU
#       6 device = torch.device("xpu")
#
# ModuleNotFoundError: No module named 'intel_extension_for_pytorch'

# %%
# First, check available GPU
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")
print(f"GPU device: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")
# Out:
# CUDA available: True
# CUDA version: 12.6
# GPU device: Tesla T4

# %% [markdown]
# # FineTuning

# %%
model = "google/pegasus-xsum"

tokenizer = AutoTokenizer.from_pretrained(model)

model_pegasus = AutoModelForSeq2SeqLM.from_pretrained(model).to(device)
# Out:
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at google/pegasus-xsum and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Move model to device
model_pegasus = model_pegasus.to(device)
print(f"Model moved to: {device}")
# Out:
# Model moved to: cuda

# %%
#dowload & unzip data

# !wget https://github.com/krishnaik06/datasets/raw/refs/heads/main/summarizer-data.zip
# !unzip summarizer-data.zip
# Out:
# --2025-10-20 21:42:51--  https://github.com/krishnaik06/datasets/raw/refs/heads/main/summarizer-data.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/krishnaik06/datasets/refs/heads/main/summarizer-data.zip [following]
# --2025-10-20 21:42:52--  https://raw.githubusercontent.com/krishnaik06/datasets/refs/heads/main/summarizer-data.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7903594 (7.5M) [application/zip]
# Saving to: ‘summarizer-data.zip’
#
# summarizer-data.zip 100%[===================>]   7.54M  42.0MB/s    in 0.2s
#
# ...

# %%
dataset_samsum = load_from_disk('file://samsum_dataset')
dataset_samsum
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'dialogue', 'summary'],
#         num_rows: 14732
#     })
#     test: Dataset({
#         features: ['id', 'dialogue', 'summary'],
#         num_rows: 819
#     })
#     validation: Dataset({
#         features: ['id', 'dialogue', 'summary'],
#         num_rows: 818
#     })
# })

# %%
split_lengths = [len(dataset_samsum[split])for split in dataset_samsum]

print(f"Split lengths: {split_lengths}")
print(f"Features: {dataset_samsum['train'].column_names}")
print("\nDialogue:")

print(dataset_samsum["test"][2]["dialogue"])

print("\nSummary:")

print(dataset_samsum["test"][2]["summary"])
# Out:
# Split lengths: [14732, 819, 818]
# Features: ['id', 'dialogue', 'summary']
#
# Dialogue:
# Lenny: Babe, can you help me with something?
# Bob: Sure, what's up?
# Lenny: Which one should I pick?
# Bob: Send me photos
# Lenny:  <file_photo>
# Lenny:  <file_photo>
# Lenny:  <file_photo>
# Bob: I like the first ones best
# Lenny: But I already have purple trousers. Does it make sense to have two pairs?
# Bob: I have four black pairs :D :D
# Lenny: yeah, but shouldn't I pick a different color?
# Bob: what matters is what you'll give you the most outfit options
# Lenny: So I guess I'll buy the first or the third pair then
# Bob: Pick the best quality then
# Lenny: ur right, thx
# Bob: no prob :)
#
# Summary:
# Lenny can't decide which trousers to buy. Bob advised Lenny on that topic. Lenny goes with Bob's advice to pick the trousers that are of best quality.

# %% [markdown]
# ### Preparing Data For Training For Sequence To Sequence Model

# %%
# Fixed data preprocessing function
def convert_examples_to_features(example_batch):
    input_encodings = tokenizer(
        example_batch['dialogue'],
        max_length=512,
        truncation=True,
        padding="max_length"
    )

    with tokenizer.as_target_tokenizer():
        target_encodings = tokenizer(
            example_batch['summary'],
            max_length=128,  # Reduced from 64 to 128 for better coverage
            truncation=True,
            padding="max_length"
        )

    return {
        'input_ids': input_encodings['input_ids'],
        'attention_mask': input_encodings['attention_mask'],
        'labels': target_encodings['input_ids']
    }

# %%
# Apply preprocessing
dataset_samsum_pt = dataset_samsum.map(convert_examples_to_features, batched=True)
# Out:
# Map:   0%|          | 0/14732 [00:00<?, ? examples/s]
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:4034: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# ...
# Map:   0%|          | 0/818 [00:00<?, ? examples/s]

# %%
dataset_samsum_pt['test']
# Out:
# Dataset({
#     features: ['id', 'dialogue', 'summary', 'input_ids', 'attention_mask', 'labels'],
#     num_rows: 819
# })

# %%
dataset_samsum_pt['validation']
# Out:
# Dataset({
#     features: ['id', 'dialogue', 'summary', 'input_ids', 'attention_mask', 'labels'],
#     num_rows: 818
# })

# %%
# 5) sanity check for invalid token ids
def check_for_invalid_tokens(dataset, tokenizer):
    vs = tokenizer.vocab_size
    for split in ["train", "validation", "test"]:
        if split not in dataset:
            continue
        for i, ids in enumerate(dataset[split]["input_ids"]):
            if max(ids) >= vs:
                print(f"Invalid token id in {split} at row {i}: {max(ids)} >= {vs}")
                return False
        for i, labs in enumerate(dataset[split]["labels"]):
            # labels may contain -100; check remaining ids
            if len(labs)==0:
                continue
            max_lab = max([x for x in labs if x!=-100] or [-1])
            if max_lab >= vs:
                print(f"Invalid label id in {split} at row {i}: {max_lab} >= {vs}")
                return False
    print("No invalid token/label ids found.")
    return True

check_for_invalid_tokens(dataset_samsum_pt, tokenizer)
# Out:
# No invalid token/label ids found.
# True

# %% [markdown]
# #### DataCollatorForSeq2Seq is a special data collator designed for sequence-to-sequence models (e.g., Pegasus, T5, BART) that helps in preparing batches of data for training.

# %%
from transformers import DataCollatorForSeq2Seq
# Data collator
seq2seq_data_collator = DataCollatorForSeq2Seq(tokenizer, model=model_pegasus, padding=True)

# %%
import os
os.environ["WANDB_DISABLED"] = "true"

# %%
pip uninstall wandb -y
# Out:
# Found existing installation: wandb 0.22.2
# Uninstalling wandb-0.22.2:
#   Successfully uninstalled wandb-0.22.2

# %%
from transformers import TrainingArguments, Trainer
# Training arguments - optimized for Colab GPU
training_args = TrainingArguments(
    output_dir='pegasus-samsum',
    num_train_epochs=1,
    per_device_train_batch_size=2,  # Reduced batch size
    per_device_eval_batch_size=2,
    warmup_steps=100,  # Reduced warmup steps
    weight_decay=0.01,
    logging_steps=10,
    eval_strategy='steps',  # Changed from eval_strategy
    eval_steps=100,  # Reduced eval steps
    save_steps=500,
    gradient_accumulation_steps=4,  # Reduced accumulation steps
    fp16=torch.cuda.is_available(),  # Enable only if CUDA available
    dataloader_pin_memory=False,  # Disable pin memory to avoid GPU issues
    report_to="none",
    logging_dir="./logs",
)

# %%
import gc
gc.collect()
# Out:
# 81

# %%
import torch, gc

torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
# Display a small sample of the processed dataset to inspect the tensors
sample_dataset = dataset_samsum_pt["train"].select(range(5))

for i, example in enumerate(sample_dataset):
    print(f"Example {i}:")
    print(f"  input_ids shape: {torch.tensor(example['input_ids']).shape}, dtype: {torch.tensor(example['input_ids']).dtype}")
    print(f"  attention_mask shape: {torch.tensor(example['attention_mask']).shape}, dtype: {torch.tensor(example['attention_mask']).dtype}")
    print(f"  labels shape: {torch.tensor(example['labels']).shape}, dtype: {torch.tensor(example['labels']).dtype}")
    print("-" * 20)
# Out:
# Example 0:
#   input_ids shape: torch.Size([512]), dtype: torch.int64
#   attention_mask shape: torch.Size([512]), dtype: torch.int64
#   labels shape: torch.Size([128]), dtype: torch.int64
# --------------------
# Example 1:
#   input_ids shape: torch.Size([512]), dtype: torch.int64
#   attention_mask shape: torch.Size([512]), dtype: torch.int64
#   labels shape: torch.Size([128]), dtype: torch.int64
# --------------------
# Example 2:
#   input_ids shape: torch.Size([512]), dtype: torch.int64
#   attention_mask shape: torch.Size([512]), dtype: torch.int64
#   labels shape: torch.Size([128]), dtype: torch.int64
# --------------------
# Example 3:
#   input_ids shape: torch.Size([512]), dtype: torch.int64
#   attention_mask shape: torch.Size([512]), dtype: torch.int64
#   labels shape: torch.Size([128]), dtype: torch.int64
# --------------------
# Example 4:
#   input_ids shape: torch.Size([512]), dtype: torch.int64
#   attention_mask shape: torch.Size([512]), dtype: torch.int64
# ...

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.environ["TORCH_USE_CUDA_DSA"] = "1"
os.environ["WANDB_DISABLED"] = "true"
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# Create trainer with smaller subset for testing
train_dataset = dataset_samsum_pt["train"].select(range(100))  # Small subset for testing
eval_dataset = dataset_samsum_pt["validation"].select(range(20))

# %%
trainer = Trainer(
    model=model_pegasus,
    args=training_args,
    tokenizer=tokenizer,  # Fixed parameter name
    data_collator=seq2seq_data_collator,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset
)
# Out:
# /tmp/ipython-input-2811893907.py:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
print("Tokenizer vocab size:", len(tokenizer))
print("Model vocab size:", model_pegasus.config.vocab_size)
# Out:
# Tokenizer vocab size: 96103
# Model vocab size: 96103

# %%
model_pegasus.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(96103, 1024, padding_idx=0)

# %%
tokenizer.pad_token = tokenizer.eos_token or "</s>"
tokenizer.bos_token = tokenizer.eos_token or "<s>"
model_pegasus.config.pad_token_id = tokenizer.pad_token_id
model_pegasus.config.eos_token_id = tokenizer.eos_token_id
model_pegasus.config.bos_token_id = tokenizer.bos_token_id

# %%
max_token_id = max(max(example["input_ids"]) for example in dataset_samsum_pt["train"])
print("Max token ID in dataset:", max_token_id)
print("Tokenizer vocab size:", len(tokenizer))
# Out:
# Max token ID in dataset: 96092
# Tokenizer vocab size: 96103

# %%
dataset_samsum_pt = dataset_samsum.map(convert_examples_to_features, batched=True)
# Out:
# Map:   0%|          | 0/14732 [00:00<?, ? examples/s]
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:4034: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# ...
# Map:   0%|          | 0/818 [00:00<?, ? examples/s]

# %%
# Clear GPU memory before training
import gc
torch.cuda.empty_cache()
gc.collect()

# Start training
try:
    trainer.train()
except RuntimeError as e:
    print(f"Training error: {e}")
    print("This might be due to GPU memory issues. Try reducing batch size further.")
# Out:
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': 1, 'pad_token_id': 1}.
#     <div>
#
#       <progress value='13' max='13' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [13/13 05:36, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ...

# %%
# Get a single batch from the training dataloader
train_dataloader = trainer.get_train_dataloader()
batch = next(iter(train_dataloader))

# Check the max values in input_ids and labels
max_input_id_batch = torch.max(batch['input_ids'])
max_label_id_batch = torch.max(batch['labels'][batch['labels'] != -100]) # Ignore padding token -100

print(f"Max input ID in batch: {max_input_id_batch}")
print(f"Max label ID in batch (ignoring -100): {max_label_id_batch}")
print(f"Tokenizer vocabulary size: {tokenizer.vocab_size}")
# Out:
# Max input ID in batch: 66449
# Max label ID in batch (ignoring -100): 66449
# Tokenizer vocabulary size: 96103

# %%
# Explicitly check max token and label IDs in the processed dataset
for split in ["train", "validation"]:
    if split not in dataset_samsum_pt:
        continue
    for i, example in enumerate(dataset_samsum_pt[split]):
        max_input_id = torch.max(torch.tensor(example['input_ids']))
        # Filter out -100 before converting to tensor for max calculation
        label_tensor = torch.tensor([x for x in example['labels'] if x != -100])
        max_label_id = torch.max(label_tensor) if label_tensor.numel() > 0 else -1 # Handle empty tensor case

        vocab_size = tokenizer.vocab_size

        if max_input_id >= vocab_size:
            print(f"Invalid input token id in {split} at row {i}: {max_input_id} >= {vocab_size}")
        if max_label_id != -1 and max_label_id >= vocab_size:
            print(f"Invalid label id in {split} at row {i}: {max_label_id} >= {vocab_size}")

    print(f"Finished checking {split} split.")
# Out:
# Finished checking train split.
# Finished checking validation split.

# %%
# Evaluation
### lst[1,2,3,4,5,6]-> [1,2,3][4,5,6]
def generate_batch_sized_chunks(list_of_elements, batch_size):
    """split the dataset into smaller batches that we can process simultaneously
    Yield successive batch-sized chunks from list_of_elements."""
    for i in range(0, len(list_of_elements), batch_size):
        yield list_of_elements[i : i + batch_size]



def calculate_metric_on_test_ds(dataset, metric, model, tokenizer,
                               batch_size=16, device=device,
                               column_text="dialogue",
                               column_summary="summary"):
    article_batches = list(generate_batch_sized_chunks(dataset[column_text], batch_size))
    target_batches = list(generate_batch_sized_chunks(dataset[column_summary], batch_size))

    for article_batch, target_batch in tqdm(
        zip(article_batches, target_batches), total=len(article_batches)):

        inputs = tokenizer(article_batch, max_length=1024,  truncation=True,
                        padding="max_length", return_tensors="pt")

        summaries = model.generate(input_ids=inputs["input_ids"].to(device),
                         attention_mask=inputs["attention_mask"].to(device),
                         length_penalty=0.8, num_beams=8, max_length=128)
        ''' parameter for length penalty ensures that the model does not generate sequences that are too long. '''

        # Finally, we decode the generated texts,
        # replace the  token, and add the decoded texts with the references to the metric.
        decoded_summaries = [tokenizer.decode(s, skip_special_tokens=True,
                                clean_up_tokenization_spaces=True)
               for s in summaries]

        decoded_summaries = [d.replace("", " ") for d in decoded_summaries]


        metric.add_batch(predictions=decoded_summaries, references=target_batch)

    #  Finally compute and return the ROUGE scores.
    score = metric.compute()
    return score

# %%
# !pip install evaluate
import evaluate
rouge_metric = evaluate.load('rouge')
rouge_names = ["rouge1", "rouge2", "rougeL", "rougeLsum"]
#rouge_metric = load_metric('rouge')
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.4 MB/s eta 0:00:00
# ...

# %%
rouge_metric
# Out:
# EvaluationModule(name: "rouge", module_type: "metric", features: [{'predictions': Value('string'), 'references': List(Value('string'))}, {'predictions': Value('string'), 'references': Value('string')}], usage: """
# Calculates average rouge scores for a list of hypotheses and references
# Args:
#     predictions: list of predictions to score. Each prediction
#         should be a string with tokens separated by spaces.
#     references: list of reference for each prediction. Each
#         reference should be a string with tokens separated by spaces.
#     rouge_types: A list of rouge types to calculate.
#         Valid names:
#         `"rouge{n}"` (e.g. `"rouge1"`, `"rouge2"`) where: {n} is the n-gram based scoring,
#         `"rougeL"`: Longest common subsequence based scoring.
#         `"rougeLsum"`: rougeLsum splits text using `"
# "`.
#         See details in https://github.com/huggingface/datasets/issues/617
# ...

# %%
import torch
from tqdm import tqdm

def generate_batch_sized_chunks(list_of_elements, batch_size):
    """split the dataset into smaller batches that we can process simultaneously
    Yield successive batch-sized chunks from list_of_elements."""
    for i in range(0, len(list_of_elements), batch_size):
        yield list_of_elements[i : i + batch_size]

def calculate_metric_on_test_ds(dataset, metric, model, tokenizer,
                               batch_size=4,  # Reduced batch size for stability
                               device="cuda" if torch.cuda.is_available() else "cpu",
                               column_text="dialogue",
                               column_summary="summary"):

    # Ensure model is on correct device and in eval mode
    model = model.to(device)
    model.eval()

    article_batches = list(generate_batch_sized_chunks(dataset[column_text], batch_size))
    target_batches = list(generate_batch_sized_chunks(dataset[column_summary], batch_size))

    all_predictions = []
    all_references = []

    for article_batch, target_batch in tqdm(
        zip(article_batches, target_batches), total=len(article_batches)):

        try:
            # Tokenize with safer parameters
            inputs = tokenizer(
                article_batch,
                max_length=512,  # Reduced from 1024
                truncation=True,
                padding="max_length",
                return_tensors="pt"
            )

            # Move to device
            inputs = {k: v.to(device) for k, v in inputs.items()}

            # Generate with safer parameters
            summaries = model.generate(
                input_ids=inputs["input_ids"],
                attention_mask=inputs["attention_mask"],
                length_penalty=0.8,
                num_beams=4,  # Reduced from 8
                max_length=128,
                early_stopping=True,
                no_repeat_ngram_size=2  # Prevent repetition
            )

            # Decode generated texts
            decoded_summaries = [
                tokenizer.decode(
                    s,
                    skip_special_tokens=True,
                    clean_up_tokenization_spaces=True
                ) for s in summaries.cpu()  # Move to CPU for decoding
            ]

            # Clean up (fixed the replace operation)
            decoded_summaries = [d.replace("<n>", " ").replace("</s>", "") for d in decoded_summaries]

            all_predictions.extend(decoded_summaries)
            all_references.extend(target_batch)

        except Exception as e:
            print(f"Error in batch processing: {e}")
            # Add placeholder predictions for failed batch
            all_predictions.extend([""] * len(target_batch))
            all_references.extend(target_batch)
            continue

    # Compute final metric
    score = metric.compute(predictions=all_predictions, references=all_references)
    return score, all_predictions, all_references

# %%
# Debug: Check model and device status
print("=== Debug Information ===")
print(f"Model device: {next(trainer.model.parameters()).device}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"Device variable: {device}")

# Test with a small subset first
test_subset = dataset_samsum['test'].select(range(5))  # Small test first

print("\n=== Testing with small subset ===")
try:
    # Set environment variable for better error reporting
    import os
    os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

    score_small, predictions_small, references_small = calculate_metric_on_test_ds(
        test_subset,
        rouge_metric,
        trainer.model,
        tokenizer,
        batch_size=2  # Very small batch for testing
    )

    print("Small test successful!")
    print(f"ROUGE scores: {score_small}")

except Exception as e:
    print(f"Error in small test: {e}")
    print("Trying CPU-only approach...")

    # Force CPU execution
    score_small, predictions_small, references_small = calculate_metric_on_test_ds(
        test_subset,
        rouge_metric,
        trainer.model,
        tokenizer,
        batch_size=2,
        device="cpu"  # Force CPU
    )
    print("CPU test successful!")
# Out:
# === Debug Information ===
# Model device: cuda:0
# CUDA available: True
# Device variable: cuda
#
# === Testing with small subset ===
# 100%|██████████| 3/3 [00:08<00:00,  2.79s/it]
# Small test successful!
# ROUGE scores: {'rouge1': np.float64(0.25499214722744135), 'rouge2': np.float64(0.04857571214392804), 'rougeL': np.float64(0.17399951823481236), 'rougeLsum': np.float64(0.17590730837789664)}

# %%
# Now run the full evaluation
print("=== Running Full Evaluation ===")

try:
    # Use smaller batch size and safer parameters
    score, predictions, references = calculate_metric_on_test_ds(
        dataset_samsum['test'].select(range(20)),  # Limit to 20 samples for testing
        rouge_metric,
        trainer.model,
        tokenizer,
        batch_size=2,  # Small batch size
        device="cpu"  # Use CPU to avoid CUDA issues
    )

    # Display results
    rouge_names = ["rouge1", "rouge2", "rougeL", "rougeLsum"]
    rouge_dict = {rn: score[rn] for rn in rouge_names}

    import pandas as pd
    results_df = pd.DataFrame(rouge_dict, index=['pegasus'])
    print("\n=== ROUGE Scores ===")
    print(results_df)

    # Display some examples
    print("\n=== Sample Predictions ===")
    for i in range(min(3, len(predictions))):
        print(f"Sample {i+1}:")
        print(f"Reference: {references[i]}")
        print(f"Prediction: {predictions[i]}")
        print("-" * 80)

except Exception as e:
    print(f"Error in main evaluation: {e}")

    # Last resort: Manual evaluation
    print("Trying manual evaluation...")
    manual_predictions = []
    manual_references = []

    model_gpu = trainer.model.to('gpu')
    model_gpu.eval()

    for i in range(min(10, len(dataset_samsum['test']))):
        try:
            dialogue = dataset_samsum['test'][i]['dialogue']
            reference = dataset_samsum['test'][i]['summary']

            inputs = tokenizer(dialogue, return_tensors="pt", max_length=512, truncation=True)

            with torch.no_grad():
                summary_ids = model_cpu.generate(
                    inputs["input_ids"],
                    attention_mask=inputs["attention_mask"],
                    max_length=128,
                    num_beams=4,
                    length_penalty=0.8,
                    early_stopping=True
                )

            prediction = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
            manual_predictions.append(prediction)
            manual_references.append(reference)

        except Exception as e2:
            print(f"Error in manual sample {i}: {e2}")
            manual_predictions.append("")
            manual_references.append(dataset_samsum['test'][i]['summary'])

    # Compute final metric
    manual_score = rouge_metric.compute(predictions=manual_predictions, references=manual_references)
    rouge_dict = {rn: manual_score[rn] for rn in rouge_names}
    results_df = pd.DataFrame(rouge_dict, index=['pegasus'])
    print("\n=== Manual Evaluation ROUGE Scores ===")
    print(results_df)
# Out:
# === Running Full Evaluation ===
# 100%|██████████| 10/10 [04:08<00:00, 24.85s/it]
# === ROUGE Scores ===
#           rouge1    rouge2    rougeL  rougeLsum
# pegasus  0.20957  0.027816  0.154365   0.154904
#
# === Sample Predictions ===
# Sample 1:
# Reference: Hannah needs Betty's number but Amanda doesn't have it. She needs to contact Larry.
# Prediction: Amanda: Hey Hannah, do you have Betty's number?
# --------------------------------------------------------------------------------
# Sample 2:
# Reference: Eric and Rob are going to watch a stand-up on youtube.
# Prediction: Rob: That's so gr8!
# --------------------------------------------------------------------------------
# Sample 3:
# Reference: Lenny can't decide which trousers to buy. Bob advised Lenny on that topic. Lenny goes with Bob's advice to pick the trousers that are of best quality.
# Prediction: Bob: I've got two pairs of trousers.
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Interpreting Good vs. Bad ROUGE Scores:
# 1. Scores close to 1: This indicates a strong overlap between the generated summary and the reference summary, which is desirable in summarization tasks. For example, an F1-score of 0.7 or higher across metrics is generally considered good.
# 2. Scores between 0.5 and 0.7: Indicates moderate overlap. The summary might be capturing key points but is likely missing some structure or important information.
# 3. Scores below 0.5: Suggest a poor match between the generated and reference summaries. The model might be generating irrelevant or incomplete summaries that don’t capture the key ideas well.

# %%
## Save model
model_pegasus.save_pretrained("pegasus-samsum-model")

# %%
## Save tokenizer
tokenizer.save_pretrained("tokenizer")
# Out:
# ('tokenizer/tokenizer_config.json',
#  'tokenizer/special_tokens_map.json',
#  'tokenizer/spiece.model',
#  'tokenizer/added_tokens.json',
#  'tokenizer/tokenizer.json')

# %%
#Load

tokenizer = AutoTokenizer.from_pretrained("/content/tokenizer")

# %%
gen_kwargs = {"length_penalty": 0.8, "num_beams":8, "max_length": 128}



sample_text = dataset_samsum["test"][0]["dialogue"]

reference = dataset_samsum["test"][0]["summary"]

pipe = pipeline("summarization", model="pegasus-samsum-model",tokenizer=tokenizer)

##
print("Dialogue:")
print(sample_text)


print("\nReference Summary:")
print(reference)


print("\nModel Summary:")
print(pipe(sample_text, **gen_kwargs)[0]["summary_text"])
# Out:
# Device set to use cuda:0
# Your max_length is set to 128, but your input_length is only 122. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=61)
# Dialogue:
# Hannah: Hey, do you have Betty's number?
# Amanda: Lemme check
# Hannah: <file_gif>
# Amanda: Sorry, can't find it.
# Amanda: Ask Larry
# Amanda: He called her last time we were at the park together
# Hannah: I don't know him well
# Hannah: <file_gif>
# Amanda: Don't be shy, he's very nice
# Hannah: If you say so..
# Hannah: I'd rather you texted him
# Amanda: Just text him 🙂
# Hannah: Urgh.. Alright
# Hannah: Bye
# Amanda: Bye bye
#
# Reference Summary:
# Hannah needs Betty's number but Amanda doesn't have it. She needs to contact Larry.
#
# Model Summary:
# Amanda: Hey Hannah, do you have Betty's number? Amanda: Lemme check Hannah: file_gif> Amanda: Sorry, can't find it.
